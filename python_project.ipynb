# %%
import pandas as pd
test = pd.read_csv('python.csv')
print(test.iloc[:120, [0,20,21,22,26,27]])
# Out:
#      Unnamed: 0  Germany   France   Italy   Switzerland   Austria
# 0     1978 Jan      3,955    2,526   2,266         2,185       na
# 1     1978 Feb      4,484    2,694   2,192         1,596       na
# 2     1978 Mar      5,583    2,771   2,002         1,461       na
# 3     1978 Apr      5,309    3,183   1,677         1,472       na
# 4     1978 May      3,491    2,248   1,028         1,189       na
# 5     1978 Jun      2,806    1,778     830           853       na
# 6     1978 Jul      4,174    4,386   1,195         1,823       na
# 7     1978 Aug      4,834    6,695   3,408         1,417       na
# 8     1978 Sep      4,128    2,980   1,445         1,383       na
# 9     1978 Oct      5,098    2,693   1,254         2,052       na
# 10    1978 Nov      6,087    3,075   1,998         1,903       na
# 11    1978 Dec      5,042    2,003   1,618         1,672       na
# 12    1979 Jan      5,510    2,796   2,567         1,850       na
# ...

# %%
test.columns
# Out:
# Index(['Unnamed: 0', ' Brunei Darussalam ', ' Indonesia ', ' Malaysia ',
#        ' Philippines ', ' Thailand ', ' Viet Nam ', ' Myanmar ', ' Japan ',
#        ' Hong Kong ', ' China ', ' Taiwan ', ' Korea, Republic Of ', ' India ',
#        ' Pakistan ', ' Sri Lanka ', ' Saudi Arabia ', ' Kuwait ', ' UAE ',
#        ' United Kingdom ', ' Germany ', ' France ', ' Italy ', ' Netherlands ',
#        ' Greece ', ' Belgium & Luxembourg ', ' Switzerland ', ' Austria ',
#        ' Scandinavia ', ' CIS & Eastern Europe ', ' USA ', ' Canada ',
#        ' Australia ', ' New Zealand ', ' Africa '],
#       dtype='object')

# %%
test.loc[:120, :]
# Out:
#      Unnamed: 0  Brunei Darussalam   Indonesia   Malaysia   Philippines   \
# 0     1978 Jan                  na          na         na            na
# 1     1978 Feb                  na          na         na            na
# 2     1978 Mar                  na          na         na            na
# 3     1978 Apr                  na          na         na            na
# 4     1978 May                  na          na         na            na
# 5     1978 Jun                  na          na         na            na
# 6     1978 Jul                  na          na         na            na
# 7     1978 Aug                  na          na         na            na
# 8     1978 Sep                  na          na         na            na
# 9     1978 Oct                  na          na         na            na
# 10    1978 Nov                  na          na         na            na
# 11    1978 Dec                  na          na         na            na
# ...

# %%
test.iloc[:120, [0,20,21,22,26,27]]
# Out:
#      Unnamed: 0  Germany   France   Italy   Switzerland   Austria
# 0     1978 Jan      3,955    2,526   2,266         2,185       na
# 1     1978 Feb      4,484    2,694   2,192         1,596       na
# 2     1978 Mar      5,583    2,771   2,002         1,461       na
# 3     1978 Apr      5,309    3,183   1,677         1,472       na
# 4     1978 May      3,491    2,248   1,028         1,189       na
# 5     1978 Jun      2,806    1,778     830           853       na
# 6     1978 Jul      4,174    4,386   1,195         1,823       na
# 7     1978 Aug      4,834    6,695   3,408         1,417       na
# 8     1978 Sep      4,128    2,980   1,445         1,383       na
# 9     1978 Oct      5,098    2,693   1,254         2,052       na
# 10    1978 Nov      6,087    3,075   1,998         1,903       na
# 11    1978 Dec      5,042    2,003   1,618         1,672       na
# 12    1979 Jan      5,510    2,796   2,567         1,850       na
# ...

# %%
year = [1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987]
pop_Germany = [54991, 63540, 73039, 79834, 68114, 67341, 72787, 73883, 78395, 93319]
pop_France = [37032, 42041, 40236, 44664, 41139, 37065, 42207, 41436, 43571, 47472]
plt.plot(year, pop_Germany, color='red')
plt.plot(year, pop_France, color='orange')
plt.xlabel('Year')
plt.ylabel('Germany & France')
plt.title('Europe 1978 - 1987')
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('Germany', 'France', 'Italy', 'Switzerland', 'Austria')
y_pos = np.arange(len(objects))
performance = [725243, 416863, 259197, 273298, 14805]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Countries')
plt.title('Europe 1978 - 1987')

plt.show()
